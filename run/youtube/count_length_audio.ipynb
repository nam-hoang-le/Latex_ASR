# %%
import os

# Change to the root directory (one level up from 'test')
os.chdir('../..')

# %%
folder_path = os.getcwd()
print(folder_path)
# Out:
# d:\Projects\3. Latex

# %%
from utils.youtube.count_length_audio import process_audio_files_in_nested_folders

# %%
# Use the function with the path to the main 'audio' folder
audio_path = folder_path + "/data/audio/mathematics"  # Path to the root folder (e.g., 'audio')
process_audio_files_in_nested_folders(audio_path)
# Out:
# File: audio_1.mp3, Duration: 2788.90 seconds
# File: audio_10.mp3, Duration: 3009.75 seconds
# File: audio_11.mp3, Duration: 2565.67 seconds
# File: audio_12.mp3, Duration: 2995.93 seconds
# File: audio_13.mp3, Duration: 3069.13 seconds
# File: audio_14.mp3, Duration: 2934.65 seconds
# File: audio_15.mp3, Duration: 2291.46 seconds
# File: audio_16.mp3, Duration: 1099.00 seconds
# File: audio_17.mp3, Duration: 3044.47 seconds
# File: audio_18.mp3, Duration: 2980.39 seconds
# File: audio_19.mp3, Duration: 3008.84 seconds
# File: audio_2.mp3, Duration: 2739.58 seconds
# File: audio_20.mp3, Duration: 2939.27 seconds
# File: audio_21.mp3, Duration: 2965.79 seconds
# File: audio_22.mp3, Duration: 2865.76 seconds
# File: audio_23.mp3, Duration: 2987.99 seconds
# File: audio_24.mp3, Duration: 2928.67 seconds
# File: audio_25.mp3, Duration: 2894.89 seconds
# File: audio_26.mp3, Duration: 2992.25 seconds
# File: audio_27.mp3, Duration: 3033.52 seconds
# ...
